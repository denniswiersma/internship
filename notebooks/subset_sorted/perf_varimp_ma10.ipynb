# %%
import os
from pathlib import Path

project_root = Path.cwd().parent.parent
os.chdir(project_root)
print(os.getcwd())
# Out:
# /homes/dwiersma/Desktop/internship

# %% [markdown]
# # Using the best model

# %%
import pickle as pkl
import tomllib

from src.ml.cforest import Cforest
from src.data import Data

# load config
with open("config.toml", "rb") as file:
    config = tomllib.load(file)

# load the microarray data (set in config.toml), not important here though
data = Data(config)

data.replace_sample_sep(".")

tcga_data = data.get_mm_with_tt()
tcga_data.columns = tcga_data.columns.str.replace(" ", "_")
print(f"tcga_data shape: {tcga_data.shape}")
# Out:
# 2024-01-15 14:58:57,690:src.log_manager:INFO:Loading data...
# 2024-01-15 14:59:47,615:src.log_manager:INFO:Data loaded in 49.9234 seconds
# tcga_data shape: (15403, 9710)

# %%
import pandas as pd

tcga_data = pd.read_csv("data/subsets_sorted/tcga_10ct_min100s.csv")

tcga_data = tcga_data.set_index("samples")

tcga_data.columns = tcga_data.columns.str.replace(" ", "_")

tcga_data
# Out:
#                                                 response  \
# samples
# TCGA.3Z.A93Z.01A.11R.A37O.07  Renal clear cell carcinoma
# TCGA.6D.AA2E.01A.11R.A37O.07  Renal clear cell carcinoma
# TCGA.A3.3306.01A.01R.0864.07  Renal clear cell carcinoma
# TCGA.A3.3307.01A.01R.0864.07  Renal clear cell carcinoma
# TCGA.A3.3308.01A.02R.1325.07  Renal clear cell carcinoma
# ...                                                  ...
# TCGA.AB.3007.03A.01T.0736.13      Acute myeloid leukemia
# TCGA.AB.3008.03A.01T.0736.13      Acute myeloid leukemia
# TCGA.AB.3009.03A.01T.0736.13      Acute myeloid leukemia
# TCGA.AB.3011.03A.01T.0736.13      Acute myeloid leukemia
# TCGA.AB.3012.03A.01T.0736.13      Acute myeloid leukemia
#
#                               consensus_independent_component_1  \
# samples
# TCGA.3Z.A93Z.01A.11R.A37O.07                          -1.644787
# TCGA.6D.AA2E.01A.11R.A37O.07                          -0.437828
# TCGA.A3.3306.01A.01R.0864.07                          -1.710429
# TCGA.A3.3307.01A.01R.0864.07                          -1.646804
# TCGA.A3.3308.01A.02R.1325.07                          -1.822252
# ...                                                         ...
# TCGA.AB.3007.03A.01T.0736.13                           1.094287
# TCGA.AB.3008.03A.01T.0736.13                          -1.217767
# TCGA.AB.3009.03A.01T.0736.13                           0.546353
# TCGA.AB.3011.03A.01T.0736.13                          -0.725458
# TCGA.AB.3012.03A.01T.0736.13                           0.077619
#
#                               consensus_independent_component_2  \
# samples
# TCGA.3Z.A93Z.01A.11R.A37O.07                          -0.476637
# TCGA.6D.AA2E.01A.11R.A37O.07                          -0.190469
# TCGA.A3.3306.01A.01R.0864.07                          -0.564506
# TCGA.A3.3307.01A.01R.0864.07                          -0.490877
# TCGA.A3.3308.01A.02R.1325.07                           0.331602
# ...                                                         ...
# TCGA.AB.3007.03A.01T.0736.13                          -0.313363
# TCGA.AB.3008.03A.01T.0736.13                           0.897813
# TCGA.AB.3009.03A.01T.0736.13                          -0.003968
# TCGA.AB.3011.03A.01T.0736.13                           0.522038
# TCGA.AB.3012.03A.01T.0736.13                           0.555664
#
#                               consensus_independent_component_3  \
# samples
# TCGA.3Z.A93Z.01A.11R.A37O.07
# samples
# TCGA.3Z.A93Z.01A.11R.A37O.07                              1.576878
# TCGA.6D.AA2E.01A.11R.A37O.07                             -0.363826
# TCGA.A3.3306.01A.01R.0864.07                              1.073813
# TCGA.A3.3307.01A.01R.0864.07                              1.003105
# TCGA.A3.3308.01A.02R.1325.07                             -0.305227
# ...                                                            ...
# TCGA.AB.3007.03A.01T.0736.13                             -1.004293
# TCGA.AB.3008.03A.01T.0736.13                             -0.559852
# TCGA.AB.3009.03A.01T.0736.13                             -0.068334
# TCGA.AB.3011.03A.01T.0736.13                              0.312089
# TCGA.AB.3012.03A.01T.0736.13                             -0.656348
#
#                               consensus_independent_component_9709
# samples
# TCGA.3Z.A93Z.01A.11R.A37O.07                              0.065968
# TCGA.6D.AA2E.01A.11R.A37O.07                              2.543796
# TCGA.A3.3306.01A.01R.0864.07                              0.124762
# TCGA.A3.3307.01A.01R.0864.07                             -0.254212
# TCGA.A3.3308.01A.02R.1325.07                             -0.995207
# ...                                                            ...
# TCGA.AB.3007.03A.01T.0736.13                              0.005497
# TCGA.AB.3008.03A.01T.0736.13                              0.281643
# TCGA.AB.3009.03A.01T.0736.13                              0.493166
# TCGA.AB.3011.03A.01T.0736.13                              0.169590
# TCGA.AB.3012.03A.01T.0736.13                             -1.329742
#
# [4404 rows x 9710 columns]

# %%
cforest = Cforest(data)

# ma forest
with open("/students/2023-2024/master/dwiersma/subsets_sorted/20240110230910_6867b2/cforest_model.pkl", "rb") as file:
    fitted_model = pkl.load(file)

cforest.fitted_model = fitted_model

# %%
ypredict_probs = cforest.predict(newx=tcga_data.drop(columns=["response"]), type="prob")
ypredict = cforest.predict(newx=tcga_data.drop(columns=["response"]), type="response")
cforest.runID = "ma_assessment"
cforest.assess(ytrue=tcga_data["response"], ypredict=ypredict, ypredict_probs=ypredict_probs, name="clustermap_tcga")
# Out:
# /homes/dwiersma/.cache/pypoetry/virtualenvs/internship-Uqr7VIlS-py3.12/lib/python3.12/site-packages/rpy2/robjects/pandas2ri.py:56: UserWarning: DataFrame contains duplicated elements in the index, which will lead to loss of the row names in the resulting data.frame
#   warnings.warn('DataFrame contains duplicated elements in the index, '
# /homes/dwiersma/.cache/pypoetry/virtualenvs/internship-Uqr7VIlS-py3.12/lib/python3.12/site-packages/rpy2/robjects/pandas2ri.py:56: UserWarning: DataFrame contains duplicated elements in the index, which will lead to loss of the row names in the resulting data.frame
#   warnings.warn('DataFrame contains duplicated elements in the index, '
# 2024-01-15 15:11:50,122:src.log_manager:INFO:Performance metrics
# AUC-ROC =		0.9988822841821035
# MCC =			0.9298541408936188
# ARI =			0.8892513706790438
# top-3 accuracy =	0.9925068119891008
# 2024-01-15 15:11:51,330:src.log_manager:INFO:Clustermap saved to /students/2023-2024/master/dwiersma/output/cforest/ma_assessment/clustermap_tcga.png

# %% [markdown]
# Hmm that performance isn't very good.
# Let's explore some more.

# %% [markdown]
# # Feature Importance

# %% [markdown]
# Feature importance may be calculated like below, but it may take a while. I shall therefore load it from a file.

# %%
from rpy2 import robjects
from rpy2.robjects import pandas2ri
from rpy2.robjects.packages import importr

importr("partykit")
robjects.r.assign("best_forest", cforest.fitted_model)

varimp = pd.DataFrame(robjects.r("data.frame(varimp(best_forest, cores = 50, conditional = FALSE))")).T

# %%
varimp
