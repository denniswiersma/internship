# %%
import os
from pathlib import Path

project_root = Path.cwd().parent.parent
os.chdir(project_root)
print(os.getcwd())
# Out:
# /homes/dwiersma/Desktop/internship

# %% [markdown]
# # Using the best model

# %%
import pickle as pkl
import tomllib

from src.ml.cforest import Cforest
from src.data import Data

# load config
with open("config.toml", "rb") as file:
    config = tomllib.load(file)

# load the microarray data (set in config.toml)
data = Data(config)

data.replace_sample_sep(".")

ma_data = data.get_mm_with_tt()
ma_data.columns = ma_data.columns.str.replace(" ", "_")
print(f"ma_data shape: {ma_data.shape}")
# Out:
# 2024-01-16 12:25:53,999:src.log_manager:INFO:Loading data...
# 2024-01-16 12:26:40,444:src.log_manager:INFO:Data loaded in 46.4429 seconds
# ma_data shape: (15403, 9710)

# %%
import pandas as pd

ma_data = pd.read_csv("data/subsets_sorted/ma_5ct_min100s.csv")

ma_data = ma_data.set_index("samples")

ma_data.columns = ma_data.columns.str.replace(" ", "_")

ma_data
# Out:
#                                                      response  \
# samples
# GSM1001610_1025A.CEL                      Lung adenocarcinoma
# GSM1001611_104A.CEL                       Lung adenocarcinoma
# GSM1001612_1065A.CEL                      Lung adenocarcinoma
# GSM1001613_1176B.CEL                      Lung adenocarcinoma
# GSM1001614_1179A.CEL                      Lung adenocarcinoma
# ...                                                       ...
# GSM978299_UB_AR_24032011_06KM2756.CEL  Acute myeloid leukemia
# GSM978300_UB_AR_24032011_06PB5792.CEL  Acute myeloid leukemia
# GSM978301_UB_AR_24032011_07KM4055.CEL  Acute myeloid leukemia
# GSM978302_UB_AR_24032011_07KM4218.CEL  Acute myeloid leukemia
# GSM978303_UB_AR_24032011_08PB0892.CEL  Acute myeloid leukemia
#
#                                        consensus_independent_component_1  \
# samples
# GSM1001610_1025A.CEL                                            0.495375
# GSM1001611_104A.CEL                                             0.799637
# GSM1001612_1065A.CEL                                            0.366373
# GSM1001613_1176B.CEL                                            1.411042
# GSM1001614_1179A.CEL                                           -0.856902
# ...                                                                  ...
# GSM978299_UB_AR_24032011_06KM2756.CEL                           0.053375
# GSM978300_UB_AR_24032011_06PB5792.CEL                           1.084577
# GSM978301_UB_AR_24032011_07KM4055.CEL                           0.390783
# GSM978302_UB_AR_24032011_07KM4218.CEL                           1.052818
# GSM978303_UB_AR_24032011_08PB0892.CEL                           0.055461
#
#                                        consensus_independent_component_2  \
# samples
# GSM1001610_1025A.CEL                                           -0.144994
# GSM1001611_104A.CEL                                            -0.921576
# GSM1001612_1065A.CEL                                           -0.482790
# GSM1001613_1176B.CEL                                           -0.726494
# GSM1001614_1179A.CEL                                           -0.739656
# ...                                                                  ...
# GSM978299_UB_AR_24032011_06KM2756.CEL                           0.468300
# GSM978300_UB_AR_24032011_06PB5792.CEL                           0.240337
# GSM978301_UB_AR_24032011_07KM4055.CEL                          -0.321694
# GSM978302_UB_AR_24032011_07KM4218.CEL                           1.092148
# GSM978303_UB_AR_24032011_08PB0892.CEL                          -0.305366
#
#                                        consensus_independent_component_3  \
# samples
# GSM1001610_1025A.CEL                                            0.653698
# GSM1001611_104A.CEL                                             0.656700
# GSM1001612_1065A.CEL                                            0.621760
# GSM1001613_1176B.CEL                                           -0.918696
# GSM1001614_1179A.CEL                                           -0.404778
# ...                                                                  ...
# GSM978299_UB_AR_24032011_06KM2756.CEL                          -0.022207
# GSM978300_UB_AR_24032011_06PB5792.CEL                           0.322706
# GSM978301_UB_AR_24032011_07KM4055.CEL                           0.381892
# GSM978302_UB_AR_24032011_07KM4218.CEL                           0.607650
# GSM978303_UB_AR_24032011_08PB0892.CEL                           0.172987
#
#                                        consensus_independent_component_4  \
# samples
# GSM1001610_1025A.CEL                                            0.152382
# GSM1001611_104A.CEL                                             1.470572
# GSM1001612_1065A.CEL                                            1.370997
# GSM1001613_1176B.CEL                                            0.294711
# GSM1001614_1179A.CEL                                            0.858474
# ...                                                                  ...
# GSM978299_UB_AR_24032011_06KM2756.CEL                          -1.407416
# GSM978300_UB_AR_24032011_06PB5792.CEL                          -1.066431
# GSM978301_UB_AR_24032011_07KM4055.CEL                          -1.791904
# GSM978302_UB_AR_24032011_07KM4218.CEL                          -1.375521
# GSM978303_UB_AR_24032011_08PB0892.CEL                          -2.070298
#
#                                        consensus_independent_component_5  \
# samples
# GSM1001610_1025A.CEL                                            0.974743
# GSM1001611_104A.CEL                                             1.217788
# GSM1001612_1065A.CEL                                            1.656947
# GSM1001613_1176B.CEL                                            0.930908
# GSM1001614_1179A.CEL                                            0.329020
# ...                                                                  ...
# GSM978299_UB_AR_24032011_06KM2756.CEL                          -1.360221
# GSM978300_UB_AR_24032011_06PB5792.CEL                          -1.057240
# GSM978301_UB_AR_24032011_07KM4055.CEL                          -1.817338
# GSM978302_UB_AR_24032011_07KM4218.CEL                          -0.660389
# GSM978303_UB_AR_24032011_08PB0892.CEL                          -1.359181
#
#                                        consensus_independent_component_6  \
# samples
# GSM1001610_1025A.CEL                                           -1.710693
# GSM1001611_104A.CEL                                            -1.019460
# GSM1001612_1065A.CEL                                           -1.713003
# GSM1001613_1176B.CEL                                           -0.738137
# GSM1001614_1179A.CEL                                           -0.785700
# ...                                                                  ...
# GSM978299_UB_AR_24032011_06KM2756.CEL                           0.891686
# GSM978300_UB_AR_24032011_06PB5792.CEL                          -0.386585
# GSM978301_UB_AR_24032011_07KM4055.CEL                           1.559494
# GSM978302_UB_AR_24032011_07KM4218.CEL                           0.828995
# GSM978303_UB_AR_24032011_08PB0892.CEL                          -0.529180
#
#                                        consensus_independent_component_7  \
# samples
# GSM1001610_1025A.CEL                                           -0.674743
# GSM1001611_104A.CEL                                             0.245733
# GSM1001612_1065A.CEL                                           -1.194420
# GSM1001613_1176B.CEL                                           -1.737150
# GSM1001614_1179A.CEL                                           -0.822693
# ...                                                                  ...
# GSM978299_UB_AR_24032011_06KM2756.CEL                          -0.307659
# GSM978300_UB_AR_24032011_06PB5792.CEL                          -1.332443
# GSM978301_UB_AR_24032011_07KM4055.CEL                          -1.055562
# GSM978302_UB_AR_24032011_07KM4218.CEL                          -0.924027
# GSM978303_UB_AR_24032011_08PB0892.CEL                          -0.899457
#
#                                        consensus_independent_component_8  \
# samples
# GSM1001610_1025A.CEL                                           -1.001575
# GSM1001611_104A.CEL                                             0.728797
# GSM1001612_1065A.CEL                                           -1.965064
# GSM1001613_1176B.CEL                                           -0.502270
# GSM1001614_1179A.CEL                                            2.452808
# ...                                                                  ...
# GSM978299_UB_AR_24032011_06KM2756.CEL                          -0.864755
# GSM978300_UB_AR_24032011_06PB5792.CEL                          -1.057068
# GSM978301_UB_AR_24032011_07KM4055.CEL                           1.169218
# GSM978302_UB_AR_24032011_07KM4218.CEL                           0.187943
# GSM978303_UB_AR_24032011_08PB0892.CEL                          -0.674891
#
#                                        consensus_independent_component_9  ...  \
# samples                                                                   ...
# GSM1001610_1025A.CEL                                           -0.442906  ...
# GSM1001611_104A.CEL                                             0.139614  ...
# GSM1001612_1065A.CEL                                            0.229646  ...
# GSM1001613_1176B.CEL                                           -0.324505  ...
# GSM1001614_1179A.CEL                                           -0.408857  ...
# ...                                                                  ...  ...
# GSM978299_UB_AR_24032011_06KM2756.CEL                           0.058113  ...
# GSM978300_UB_AR_24032011_06PB5792.CEL                           1.289751  ...
# GSM978301_UB_AR_24032011_07KM4055.CEL                           0.977924  ...
# GSM978302_UB_AR_24032011_07KM4218.CEL                           0.370355  ...
# GSM978303_UB_AR_24032011_08PB0892.CEL                           0.987908  ...
#
#                                        consensus_independent_component_9700  \
# samples
# GSM1001610_1025A.CEL                                               2.016707
# GSM1001611_104A.CEL                                                1.226005
# GSM1001612_1065A.CEL                                               0.187451
# GSM1001613_1176B.CEL                                               0.974812
# GSM1001614_1179A.CEL                                               1.263094
# ...                                                                     ...
# GSM978299_UB_AR_24032011_06KM2756.CEL                              0.214423
# GSM978300_UB_AR_24032011_06PB5792.CEL                             -0.042403
# GSM978301_UB_AR_24032011_07KM4055.CEL                             -0.681216
# GSM978302_UB_AR_24032011_07KM4218.CEL                              0.851923
# GSM978303_UB_AR_24032011_08PB0892.CEL                              0.036944
#
#                                        consensus_independent_component_9701  \
# samples
# GSM1001610_1025A.CEL                                              -1.916875
# GSM1001611_104A.CEL                                               -0.073671
# GSM1001612_1065A.CEL                                              -0.977721
# GSM1001613_1176B.CEL                                              -1.271406
# GSM1001614_1179A.CEL                                              -1.985830
# ...                                                                     ...
# GSM978299_UB_AR_24032011_06KM2756.CEL                             -1.079317
# GSM978300_UB_AR_24032011_06PB5792.CEL                             -1.486417
# GSM978301_UB_AR_24032011_07KM4055.CEL                             -0.859934
# GSM978302_UB_AR_24032011_07KM4218.CEL                             -0.100500
# GSM978303_UB_AR_24032011_08PB0892.CEL                             -0.506757
#
#                                        consensus_independent_component_9702  \
# samples
# GSM1001610_1025A.CEL                                              -0.279630
# GSM1001611_104A.CEL                                                0.027042
# GSM1001612_1065A.CEL                                              -1.352886
# GSM1001613_1176B.CEL                                               0.718995
# GSM1001614_1179A.CEL                                               0.442057
# ...                                                                     ...
# GSM978299_UB_AR_24032011_06KM2756.CEL                             -0.885779
# GSM978300_UB_AR_24032011_06PB5792.CEL                             -1.526273
# GSM978301_UB_AR_24032011_07KM4055.CEL                             -1.471211
# GSM978302_UB_AR_24032011_07KM4218.CEL                             -0.422296
# GSM978303_UB_AR_24032011_08PB0892.CEL                              0.217861
#
#                                        consensus_independent_component_9703  \
# samples
# GSM1001610_1025A.CEL                                               0.600953
# GSM1001611_104A.CEL                                               -0.909825
# GSM1001612_1065A.CEL                                               1.456342
# GSM1001613_1176B.CEL                                              -0.761002
# GSM1001614_1179A.CEL                                               1.048050
# ...                                                                     ...
# GSM978299_UB_AR_24032011_06KM2756.CEL                             -3.120757
# GSM978300_UB_AR_24032011_06PB5792.CEL                             -1.393095
# GSM978301_UB_AR_24032011_07KM4055.CEL                             -0.008367
# GSM978302_UB_AR_24032011_07KM4218.CEL                             -1.697143
# GSM978303_UB_AR_24032011_08PB0892.CEL                             -0.794106
#
#                                        consensus_independent_component_9704  \
# samples
# GSM1001610_1025A.CEL                                               1.377651
# GSM1001611_104A.CEL                                                1.956098
# GSM1001612_1065A.CEL                                               2.723599
# GSM1001613_1176B.CEL                                               2.387306
# GSM1001614_1179A.CEL                                               1.016874
# ...                                                                     ...
# GSM978299_UB_AR_24032011_06KM2756.CEL                             -0.497761
# GSM978300_UB_AR_24032011_06PB5792.CEL                              1.594772
# GSM978301_UB_AR_24032011_07KM4055.CEL                             -0.929349
# GSM978302_UB_AR_24032011_07KM4218.CEL                             -0.679253
# GSM978303_UB_AR_24032011_08PB0892.CEL                              2.710078
#
#                                        consensus_independent_component_9705  \
# samples
# GSM1001610_1025A.CEL                                              -1.128128
# GSM1001611_104A.CEL                                               -1.654324
# GSM1001612_1065A.CEL                                              -0.453462
# GSM1001613_1176B.CEL                                              -0.167512
# GSM1001614_1179A.CEL                                               0.356518
# ...                                                                     ...
# GSM978299_UB_AR_24032011_06KM2756.CEL                             -0.669507
# GSM978300_UB_AR_24032011_06PB5792.CEL                              0.705600
# GSM978301_UB_AR_24032011_07KM4055.CEL                              0.538256
# GSM978302_UB_AR_24032011_07KM4218.CEL                             -0.365606
# GSM978303_UB_AR_24032011_08PB0892.CEL                             -0.987805
#
#                                        consensus_independent_component_9706  \
# samples
# GSM1001610_1025A.CEL                                              -1.328154
# GSM1001611_104A.CEL                                                0.053610
# GSM1001612_1065A.CEL                                              -0.812171
# GSM1001613_1176B.CEL                                              -0.595910
# GSM1001614_1179A.CEL                                              -0.936400
# ...                                                                     ...
# GSM978299_UB_AR_24032011_06KM2756.CEL                             -1.641564
# GSM978300_UB_AR_24032011_06PB5792.CEL                             -0.171937
# GSM978301_UB_AR_24032011_07KM4055.CEL                             -2.023212
# GSM978302_UB_AR_24032011_07KM4218.CEL                             -1.770705
# GSM978303_UB_AR_24032011_08PB0892.CEL                             -0.633939
#
#                                        consensus_independent_component_9707  \
# samples
# GSM1001610_1025A.CEL                                               0.578141
# GSM1001611_104A.CEL                                                0.531980
# GSM1001612_1065A.CEL                                              -0.865397
# GSM1001613_1176B.CEL                                               0.561011
# GSM1001614_1179A.CEL                                               1.450209
# ...                                                                     ...
# GSM978299_UB_AR_24032011_06KM2756.CEL                              0.363672
# GSM978300_UB_AR_24032011_06PB5792.CEL                             -3.329642
# GSM978301_UB_AR_24032011_07KM4055.CEL                              0.944169
# GSM978302_UB_AR_24032011_07KM4218.CEL                             -0.057127
# GSM978303_UB_AR_24032011_08PB0892.CEL                             -1.779529
#
#                                        consensus_independent_component_9708  \
# samples
# GSM1001610_1025A.CEL                                              -1.893471
# GSM1001611_104A.CEL                                               -1.408957
# GSM1001612_1065A.CEL                                              -1.558949
# GSM1001613_1176B.CEL                                              -0.863321
# GSM1001614_1179A.CEL                                              -0.703490
# ...                                                                     ...
# GSM978299_UB_AR_24032011_06KM2756.CEL                              0.321270
# GSM978300_UB_AR_24032011_06PB5792.CEL                              0.536947
# GSM978301_UB_AR_24032011_07KM4055.CEL                             -0.303196
# GSM978302_UB_AR_24032011_07KM4218.CEL                              0.379645
# GSM978303_UB_AR_24032011_08PB0892.CEL                              2.427041
#
#                                        consensus_independent_component_9709
# samples
# GSM1001610_1025A.CEL                                              -2.856941
# GSM1001611_104A.CEL                                                0.909090
# GSM1001612_1065A.CEL                                               0.173424
# GSM1001613_1176B.CEL                                               2.545537
# GSM1001614_1179A.CEL                                              -0.542138
# ...                                                                     ...
# GSM978299_UB_AR_24032011_06KM2756.CEL                              1.356124
# GSM978300_UB_AR_24032011_06PB5792.CEL                              0.062358
# GSM978301_UB_AR_24032011_07KM4055.CEL                              0.141655
# GSM978302_UB_AR_24032011_07KM4218.CEL                              0.542024
# GSM978303_UB_AR_24032011_08PB0892.CEL                              1.233052
#
# [7310 rows x 9710 columns]

# %%
cforest = Cforest(data)

# TCGA forest
with open("/students/2023-2024/master/dwiersma/subsets_sorted/20240111125558_84891a/cforest_model.pkl", "rb") as file:
    fitted_model = pkl.load(file)

cforest.fitted_model = fitted_model

# %%
ypredict_probs = cforest.predict(newx=ma_data.drop(columns=["response"]), type="prob")
ypredict = cforest.predict(newx=ma_data.drop(columns=["response"]), type="response")
cforest.runID = "ma_assessment"
cforest.assess(ytrue=ma_data["response"], ypredict=ypredict, ypredict_probs=ypredict_probs, name="clustermap_ma")
# Out:
# 2024-01-16 12:34:38,577:src.log_manager:INFO:Performance metrics
# AUC-ROC =		0.9988825282680006
# MCC =			0.7594744328026429
# ARI =			0.7076688851180114
# top-3 accuracy =	0.9805745554035568
# 2024-01-16 12:34:39,923:src.log_manager:INFO:Clustermap saved to /students/2023-2024/master/dwiersma/output/cforest/ma_assessment/clustermap_ma.png

# %% [markdown]
# Hmm that performance isn't very good.
# Let's explore some more.

# %% [markdown]
# # Feature Importance

# %% [markdown]
# Feature importance may be calculated like below, but it may take a while. I shall therefore load it from a file.

# %%
from rpy2 import robjects
from rpy2.robjects import pandas2ri
from rpy2.robjects.packages import importr

importr("partykit")
robjects.r.assign("best_forest", cforest.fitted_model)

print(robjects.r("data.frame(varimp(best_forest, cores = 50, conditional = FALSE))"))
